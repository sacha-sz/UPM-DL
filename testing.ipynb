# %%
from training import train_model
from testing import test_model, render_layer_output

# %%
train_model("dataset/train", None, 40, 0.001, 3, "cnn", None, 16)
# Out:
# Number of parameters: 364026
# [1,     1] loss: 0.615
# [1,     2] loss: 0.299
# [1,     3] loss: 0.309
# [1,     4] loss: 0.383
# [1,     5] loss: 0.302
# [1,     6] loss: 0.274
# [1,     7] loss: 0.225
# [1,     8] loss: 0.159
# [1,     9] loss: 0.176
# [1,    10] loss: 0.149
# [1,    11] loss: 0.291
# [1,    12] loss: 0.155
# [1,    13] loss: 0.246
# [1,    14] loss: 0.134
# [1,    15] loss: 0.199
# [1,    16] loss: 0.363
# [1,    17] loss: 0.262
# [1,    18] loss: 0.138
# [1,    19] loss: 0.140
# [1,    20] loss: 0.186
# [1,    21] loss: 0.223
# [1,    22] loss: 0.179
# [1,    23] loss: 0.224
# [1,    24] loss: 0.130
# [1,    25] loss: 0.071
# [1,    26] loss: 0.165
# [1,    27] loss: 0.158
# [1,    28] loss: 0.178
# [1,    29] loss: 0.190
# [1,    30] loss: 0.108
# [1,    31] loss: 0.169
# [1,    32] loss: 0.166
# [1,    33] loss: 0.182
# [1,    34] loss: 0.124
# [1,    35] loss: 0.097
# [1,    36] loss: 0.096
# [1,    37] loss: 0.167
# [1,    38] loss: 0.095
# ...

# %%
test_model("models/cnn_0.001_full.pt", "cnn_testing", "dataset/test", None, architecture=6)
